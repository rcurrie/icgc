# %%
import pandas as pd

# %%
donors = pd.read_table("/data/icgc/donor.ALL-US.tsv.gz")
donors.head()
# Out:
#   icgc_donor_id project_code  study_donor_involved_in submitted_donor_id  \
# 0           DO2       ALL-US                      NaN   TARGET-10-PAIXFI
# 1           DO1       ALL-US                      NaN   TARGET-10-PAIXDK
# 2           DO4       ALL-US                      NaN   TARGET-10-PAIXGP
# 3           DO3       ALL-US                      NaN   TARGET-10-PAIXFN
# 4           DO6       ALL-US                      NaN   TARGET-10-PAIXPN
#
#   donor_sex donor_vital_status disease_status_last_followup  \
# 0      male                NaN                          NaN
# 1      male           deceased                      relapse
# 2    female              alive                          NaN
# 3      male           deceased                      relapse
# 4      male              alive                          NaN
#
#              donor_relapse_type  donor_age_at_diagnosis  \
# 0                           NaN                       5
# ...

# %%
expression = pd.read_table("/data/icgc/simple_somatic_mutation.open.ALL-US.tsv.gz")
expression.head()
# Out:
#   icgc_mutation_id icgc_donor_id project_code icgc_specimen_id icgc_sample_id  \
# 0        MU4819276           DO5       ALL-US            SP873          SA565
# 1        MU4819276           DO5       ALL-US            SP873          SA565
# 2        MU4819276           DO5       ALL-US            SP873          SA565
# 3        MU4819276           DO5       ALL-US            SP873          SA565
# 4        MU4819276           DO5       ALL-US            SP873          SA565
#
#   matched_icgc_sample_id       submitted_sample_id  \
# 0                  SA167  TARGET-10-PAIXPH-03A-01D
# 1                  SA167  TARGET-10-PAIXPH-03A-01D
# 2                  SA167  TARGET-10-PAIXPH-03A-01D
# 3                  SA167  TARGET-10-PAIXPH-03A-01D
# 4                  SA167  TARGET-10-PAIXPH-03A-01D
#
#   submitted_matched_sample_id chromosome  chromosome_start  \
# 0    TARGET-10-PAIXPH-10A-01D         12          25271550
# 1    TARGET-10-PAIXPH-10A-01D         12          25271550
# ...

# %%
variants = pd.read_table("/data/icgc/simple_somatic_mutation.open.ALL-US.tsv.gz")
variants.head()
# Out:
#   icgc_mutation_id icgc_donor_id project_code icgc_specimen_id icgc_sample_id  \
# 0        MU4819276           DO5       ALL-US            SP873          SA565
# 1        MU4819276           DO5       ALL-US            SP873          SA565
# 2        MU4819276           DO5       ALL-US            SP873          SA565
# 3        MU4819276           DO5       ALL-US            SP873          SA565
# 4        MU4819276           DO5       ALL-US            SP873          SA565
#
#   matched_icgc_sample_id       submitted_sample_id  \
# 0                  SA167  TARGET-10-PAIXPH-03A-01D
# 1                  SA167  TARGET-10-PAIXPH-03A-01D
# 2                  SA167  TARGET-10-PAIXPH-03A-01D
# 3                  SA167  TARGET-10-PAIXPH-03A-01D
# 4                  SA167  TARGET-10-PAIXPH-03A-01D
#
#   submitted_matched_sample_id chromosome  chromosome_start  \
# 0    TARGET-10-PAIXPH-10A-01D         12          25271550
# 1    TARGET-10-PAIXPH-10A-01D         12          25271550
# ...
